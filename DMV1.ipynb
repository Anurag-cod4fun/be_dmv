# %%
import numpy as np
import pandas as pd

# %%
df_csv = pd.read_csv('sales.csv')
df_csv.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df_json = pd.read_json('sales.json')
df_json.head()
# Out:
#    id                   email    first     last  \
# 0   1  isidro_von@hotmail.com   Torrey     Veum
# 1   2  frederique19@gmail.com    Micah  Sanford
# 2   3       fredy54@gmail.com   Hollis    Swift
# 3   4   braxton29@hotmail.com    Perry  Leffler
# 4   5      turner59@gmail.com  Janelle  Hagenes
#
#                           company                       created_at  \
# 0          Hilll, Mayert and Wolf 2014-12-25 04:06:27.981000+00:00
# 1                  Stokes-Reichel 2014-07-03 16:08:17.044000+00:00
# 2  Rodriguez, Cartwright and Kuhn 2014-08-18 06:15:16.731000+00:00
# 3        Sipes, Feeney and Hansen 2014-07-10 11:31:40.235000+00:00
# 4             Lesch and Daughters 2014-04-21 15:05:43.229000+00:00
#
#                                  country
# 0                            Switzerland
# 1  Democratic People's Republic of Korea
# 2                                Tunisia
# 3                                   Chad
# 4                              Swaziland

# %%
df_excel = pd.read_excel('sales.xlsx')
df_excel.head()
# Out:
#    Row ID        Order ID       Ship Mode Customer ID    Customer Name  \
# 0       1  CA-2016-152156    Second Class    CG-12520      Claire Gute
# 1       2  CA-2016-152156    Second Class    CG-12520      Claire Gute
# 2       3  CA-2016-138688    Second Class    DV-13045  Darrin Van Huff
# 3       4  US-2015-108966  Standard Class    SO-20335   Sean O'Donnell
# 4       5  US-2015-108966  Standard Class    SO-20335   Sean O'Donnell
#
#      Segment        Country             City       State  Postal Code Region  \
# 0   Consumer  United States        Henderson    Kentucky        42420  South
# 1   Consumer  United States        Henderson    Kentucky        42420  South
# 2  Corporate  United States      Los Angeles  California        90036   West
# 3   Consumer  United States  Fort Lauderdale     Florida        33311  South
# 4   Consumer  United States  Fort Lauderdale     Florida        33311  South
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df_csv.isnull().sum()
# Out:
# Order ID            59
# Product             59
# Quantity Ordered    59
# Price Each          59
# Order Date          59
# Purchase Address    59
# dtype: int64

# %%
df_csv.dropna(inplace=True)
df_json.dropna(inplace=True)
df_excel.dropna(inplace=True)

# %%
print(df_csv.shape)
print(df_json.shape)
print(df_excel.shape)
# Out:
# (18324, 6)
# (9999, 7)
# (9994, 19)

# %%
df1 = df_csv.iloc[:9000, :]
df2 = df_json.iloc[:9000, :]
df3 = df_excel.iloc[:9000, :]

# %%
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (9000, 6)
# (9000, 7)
# (9000, 19)

# %%
df_merged = pd.concat([df1,df2,df3], axis=1)

# %%
df_merged.dropna(inplace=True)

# %%
df_merged
# Out:
#      Order ID                     Product Quantity Ordered Price Each  \
# 0      176558        USB-C Charging Cable                2      11.95
# 2      176559  Bose SoundSport Headphones                1      99.99
# 3      176560                Google Phone                1        600
# 4      176560            Wired Headphones                1      11.99
# 5      176561            Wired Headphones                1      11.99
# ...       ...                         ...              ...        ...
# 8995   185147       AA Batteries (4-pack)                1       3.84
# 8996   185148      AAA Batteries (4-pack)                1       2.99
# 8997   185149       AA Batteries (4-pack)                1       3.84
# 8998   185150            Wired Headphones                1      11.99
# 8999   185151       AA Batteries (4-pack)                1       3.84
#
#           Order Date                        Purchase Address      id  \
# 0     04/19/19 08:46            917 1st St, Dallas, TX 75001     1.0
# 2     04/07/19 22:30       682 Chestnut St, Boston, MA 02215     3.0
# 3     04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001     4.0
# 4     04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001     5.0
# 5     04/30/19 09:27       333 8th St, Los Angeles, CA 90001     6.0
# ...              ...                                     ...     ...
# 8995  04/08/19 17:49     919 North St, Los Angeles, CA 90001  8996.0
# 8996  04/16/19 08:21  762 Center St, San Francisco, CA 94016  8997.0
# 8997  04/25/19 09:20     166 6th St, San Francisco, CA 94016  8998.0
# 8998  04/11/19 11:13        504 Willow St, Atlanta, GA 30301  8999.0
# 8999  04/29/19 13:40        182 Ridge St, Portland, OR 97035  9000.0
#
#                           email    first      last  ... Postal Code   Region  \
# 0        isidro_von@hotmail.com   Torrey      Veum  ...     42420.0    South
# 2             fredy54@gmail.com   Hollis     Swift  ...     90036.0     West
# 3         braxton29@hotmail.com    Perry   Leffler  ...     33311.0    South
# 4            turner59@gmail.com  Janelle   Hagenes  ...     33311.0    South
# 5             halie47@yahoo.com  Charity   Bradtke  ...     90032.0     West
# ...                         ...      ...       ...  ...         ...      ...
# 8995  kali.leuschke38@yahoo.com   Ismael    Sawayn  ...     33021.0    South
# 8996     victoria63@hotmail.com  Durward    Beahan  ...     75081.0  Central
# 8997    nedra.doyle97@yahoo.com   Margot  Schmeler  ...     77041.0  Central
# 8998      kareem.rath@gmail.com    Devan      Feil  ...     77041.0  Central
# 8999     ian.mckenzie@yahoo.com   Jasper    Daniel  ...     19140.0     East
#
#            Product ID         Category Sub-Category  \
# 0     FUR-BO-10001798        Furniture    Bookcases
# 2     OFF-LA-10000240  Office Supplies       Labels
# 3     FUR-TA-10000577        Furniture       Tables
# 4     OFF-ST-10000760  Office Supplies      Storage
# 5     FUR-FU-10001487        Furniture  Furnishings
# ...               ...              ...          ...
# 8995  OFF-AP-10004708  Office Supplies   Appliances
# 8996  TEC-PH-10004531       Technology       Phones
# 8997  OFF-PA-10000474  Office Supplies        Paper
# 8998  OFF-PA-10002377  Office Supplies        Paper
# 8999  FUR-CH-10001482        Furniture       Chairs
#
#                                            Product Name     Sales Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600      2.0
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200      2.0
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775      5.0
# 4                        Eldon Fold 'N Roll Cart System   22.3680      2.0
# 5     Eldon Expressions Wood and Plastic Desk Access...   48.8600      7.0
# ...                                                 ...       ...      ...
# 8995  Fellowes Superior 10 Outlet Split Surge Protector  152.2400      5.0
# 8996      OtterBox Commuter Series Case - iPhone 5 & 5s   35.1840      2.0
# 8997                                  Easy-staple paper   56.7040      2.0
# 8998                                         Xerox 1916  274.0640      7.0
# 8999  Office Star - Mesh Screen back chair with Viny...  458.4300      5.0
#
#      Discount    Profit
# 0        0.00   41.9136
# 2        0.00    6.8714
# 3        0.45 -383.0310
# 4        0.20    2.5164
# 5        0.00   14.1694
# ...       ...       ...
# 8995     0.20   17.1270
# 8996     0.20   12.3144
# 8997     0.20   19.1376
# 8998     0.20  102.7740
# 8999     0.30 -124.4310
#
# [8975 rows x 32 columns]

# %%
df_merged.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'id', 'email', 'first', 'last', 'company',
#        'created_at', 'country', 'Row ID', 'Order ID', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ### 1. Bar Plot - Sales by Product Category:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
df_merged.groupby('Category')['Sales'].sum().plot(kind='bar')
plt.title('Total Sales by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# ### 2. Pie Chart - Sales Distribution by Region:

# %%
df_merged.groupby('Region')['Sales'].sum().plot(kind='pie', autopct='%1.1f%%')
plt.title('Sales Distribution by Region')
plt.show()

# %% [markdown]
# ### 3. Box Plot - Sales Distribution by Product Category:

# %%
import seaborn as sns

sns.boxplot(x='Category', y='Sales', data=df_merged)
plt.title('Sales Distribution by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Sales')
plt.show()
